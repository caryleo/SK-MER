# %%
from tqdm import tqdm
import pandas as pd
import pickle
import spacy
import json
import numpy as np
import csv
from collections import defaultdict
from ast import literal_eval
import pandas as pd
from senticnet.senticnet import SenticNet

spacy_en = spacy.load("en_core_web_sm")

# %% [markdown]
# ### Labels

# %% [markdown]
# #### Labels of text: utterance tokens

# %%
# TEXT: collect sentences from data.json

data = json.load(open('../data/data.json', 'r'))

sentences = list()
num_sentences = 0
for key, item in data.items():
    sentences.extend(item['sentences'])
    num_sentences += len(item['sentences'])
#     print('{0} has {1} sentences, {2} sentences in total'.format(key, len(item['sentences']), num_sentences))
    
assert len(sentences) == num_sentences

# tokenization: clean words for conceptNet

sentences_cleaned = list()
for sentence in sentences:
    sentence = sentence.lower()
    sentences_cleaned.append([token.text for token in spacy_en.tokenizer(sentence)])
    
# get n-grams set, 1-gram for good

n = 1
ngrams_all = list()
for sentence in sentences_cleaned:
    ngrams = list()
    for i in range(len(sentence)):
        for j in range(i, max(i - n, -1), -1):
            ngrams.append("_".join(sentence[j: i + 1]))
    ngrams_all.extend(ngrams)
    
ngrams_set = set(ngrams_all)

# %%
labels_text_set = ngrams_set

# %% [markdown]
# #### Labels of audio: emotions

# %%
emotions_audio = ['neutral', 'calm', 'happy', 'sad', 'angry', 'fearful']

# %%
labels_audio_set = set(emotions_audio)
labels_audio_set_aug = set.union(labels_text_set, labels_audio_set) # 将文本中的知识信息扩充到音频中

# %% [markdown]
# #### Labels of video: objects, face expressions, actions

# %%
# prepare object labels

file_name = json.load(open('../data/labels/labels_name.json'))
label_name = dict()
label_object = list()
for index, name in file_name.items():
    label_name[int(index)] = '_'.join(name)
    label_object.append('_'.join(name))
    
labels_object_set = set(label_object)
    
# prepare action labels
file_action = json.load(open('../data/labels/memor_2.json'))

label_action = list()
flag = False
for item in file_action:
    name_video = item['video']
    name_actions = list()
    for segment in item['clips']:
        name_actions.append(segment['label'])
        
    label_action.extend(['_'.join(label.split(' ')) for label in name_actions])
    
labels_action_set = set(label_action)

# prepare face expressions
expressions_face = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']

labels_expression = set(expressions_face)

# %%
# labels_video_set = set.union(labels_expression, labels_object_set, labels_action_set)
labels_video_set = set.union(labels_object_set, labels_action_set)

# %%
labels_video_set
# Out:
# {'starfish',
#  'mitten',
#  'batter',
#  'bell',
#  'measuring_cup',
#  'parchment',
#  'sushi',
#  'bowler_hat',
#  'license_plate',
#  'candy_bar',
#  'chocolate_bar',
#  'stew',
#  'perfume',
#  'blowing_glass',
#  'grits',
#  'water_gun',
#  'dining',
#  'cream_pitcher',
#  'wagon_wheel',
#  'tiger',
#  'crouton',
#  'mascot',
#  'bookmark',
#  'owl',
#  'blinker',
#  'ski_boot',
#  'cooking_sausages',
#  'dancing_charleston',
#  'cylinder',
#  'taillight',
#  'water_heater',
#  'sail',
#  'clarinet',
#  'record_player',
#  'Sharpie',
#  'pear',
#  'bulldozer',
#  'boot',
#  'sausage',
#  'scratcher',
#  'napkin',
#  'boom_microphone',
#  'cooking_utensil',
#  'green_onion',
#  'breakdancing',
#  'dodgeball',
#  'cassette',
#  'peach',
#  'sombrero',
#  'necklace',
#  'mint_candy',
#  'pelican',
#  'quiche',
#  'soap',
#  'poncho',
#  'dress',
#  'projector',
#  'can',
#  'life_jacket',
#  'kitten',
#  'cooking_chicken',
#  'fire_extinguisher',
#  'mat',
#  'flower_arrangement',
#  'strawberry',
#  'igniter',
#  'gun',
#  'turban',
#  'crutch',
#  'armband',
#  'tennis_ball',
#  'tarp',
#  'towel_rack',
#  'hamburger',
#  'dolphin',
#  'flannel',
#  'lawn_mower',
#  'boat',
#  'honey',
#  'Rollerblade',
#  'blanket',
#  'gargoyle',
#  'rabbit',
#  'flagpole',
#  'bed',
#  'swimsuit',
#  'pennant',
#  'sweatband',
#  'paintbox',
#  'knight',
#  'helicopter',
#  'crab',
#  'propeller',
#  'detergent',
#  'catching_or_throwing_softball',
#  'drill',
#  'ham',
#  'trampoline',
#  'walrus',
#  'crib',
#  'sword',
#  'orange_juice',
#  'eye_mask',
#  'solar_array',
#  'shopping_bag',
#  'pottery',
#  'telephone_pole',
#  'beeper',
#  'gorilla',
#  'control',
#  'paper_towel',
#  'aquarium',
#  'diskette',
#  'hairnet',
#  'bath_towel',
#  'wallet',
#  'table_lamp',
#  'doing_aerobics',
#  'decorating_the_christmas_tree',
#  'fishbowl',
#  'cartwheeling',
#  'water_faucet',
#  'duck',
#  'television_camera',
#  'paintbrush',
#  'postcard',
#  'passenger_car',
#  'disc_golfing',
#  'kayak',
#  'curling_hair',
#  'nut',
#  'flipper',
#  'forklift',
#  'incense',
#  'comic_book',
#  'dumbbell',
#  'loveseat',
#  'puppet',
#  'popsicle',
#  'raft',
#  'strainer',
#  'gameboard',
#  'vat',
#  'seahorse',
#  'armoire',
#  'mirror',
#  'saddle',
#  'snowman',
#  'brassiere',
#  'climbing_ladder',
#  'earphone',
#  'bread-bin',
#  'stereo',
#  'headset',
#  'football_helmet',
#  'pew',
#  'football',
#  'jam',
#  'baseball_glove',
#  'crucifix',
#  'eclair',
#  'shirt',
#  'liquor',
#  'stirrer',
#  'turtle',
#  'shower_curtain',
#  'bait',
#  'crossing_river',
#  'bubble_gum',
#  'hair_curler',
#  'mushroom',
#  'penny',
#  'pastry',
#  'quilt',
#  'dirt_bike',
#  'gag',
#  'hummus',
#  'drumstick',
#  'coil',
#  'ski_pole',
#  'keycard',
#  'jelly_bean',
#  'melon',
#  'spatula',
#  'champagne',
#  'bookcase',
#  'chandelier',
#  'eggbeater',
#  'dresser',
#  'auctioning',
#  'horse_buggy',
#  'brushing_teeth',
#  'dustpan',
#  'bulletin_board',
#  'hatch',
#  'radish',
#  'colander',
#  'cub',
#  'cutting_pineapple',
#  'foal',
#  'sewing_machine',
#  'soya_milk',
#  'shoulder_bag',
#  'duct_tape',
#  'biking_through_snow',
#  'duckling',
#  'shot_glass',
#  'backpack',
#  'fire_engine',
#  'urn',
#  'candle_holder',
#  'bungee_jumping',
#  'wineglass',
#  'tablecloth',
#  'wagon',
#  'clip',
#  'beer_bottle',
#  'shoe',
#  'cooler',
#  'lizard',
#  'wasabi',
#  'tag',
#  'nosebag',
#  'mug',
#  'tartan',
#  'dish_antenna',
#  'ice_tea',
#  'drone',
#  'saltshaker',
#  'wall_socket',
#  'laptop_computer',
#  'doormat',
#  'piano',
#  'trash_can',
#  'rifle',
#  'paper_plate',
#  'assembling_computer',
#  'avocado',
#  'ice_skate',
#  'pinwheel',
#  'vase',
#  'ax',
#  'water_filter',
#  'faucet',
#  'jacket',
#  'keg',
#  'fruit_salad',
#  'car',
#  'drawer',
#  'book_bag',
#  'wedding_ring',
#  'tinfoil',
#  'credit_card',
#  'cincture',
#  'dental_floss',
#  'crock_pot',
#  'fire_hose',
#  'balloon_blowing',
#  'pocketknife',
#  'heater',
#  'doing_laundry',
#  'sunflower',
#  'grillroom',
#  'mousepad',
#  'blowing_nose',
#  'curtain',
#  'flash',
#  'mouse',
#  'deck_chair',
#  'rocking_chair',
#  'dribbling_basketball',
#  'strap',
#  'lettuce',
#  'cracker',
#  'coin',
#  'elk',
#  'belt_buckle',
#  'valve',
#  'hummingbird',
#  'wristlet',
#  'speaker',
#  'cock',
#  'bolt',
#  'cornbread',
#  'puffer',
#  'medicine',
#  'step_stool',
#  'cauliflower',
#  'beaker',
#  'drinking_fountain',
#  'cougar',
#  'cabinet',
#  'waffle_iron',
#  'building_shed',
#  'clapping',
#  'elephant',
#  'umbrella',
#  'anklet',
#  'pita',
#  'lamb',
#  'paperweight',
#  'dancing_macarena',
#  'beer_can',
#  'handsaw',
#  'doorknob',
#  'pistol',
#  'handle',
#  'string_cheese',
#  'wing_chair',
#  'cow',
#  'pin',
#  'penguin',
#  'cap',
#  'knitting_needle',
#  'barrette',
#  'folding_chair',
#  'oregano',
#  'squirrel',
#  'garlic',
#  'dancing_ballet',
#  'eel',
#  'windmill',
#  'videotape',
#  'monitor',
#  'police_cruiser',
#  'brushing_hair',
#  'soupspoon',
#  'blowing_leaves',
#  'chessboard',
#  'walking_cane',
#  'volleyball',
#  'birthday_card',
#  'earplug',
#  'pop',
#  'tote_bag',
#  'seashell',
#  'tray',
#  'climbing_tree',
#  'sherbert',
#  'portrait',
#  'shower_head',
#  'pumpkin',
#  'hot_sauce',
#  'pillow',
#  'Tabasco_sauce',
#  'robe',
#  'applauding',
#  'mixer',
#  'motor_scooter',
#  'baby_buggy',
#  'cat',
#  'neckerchief',
#  'deadlifting',
#  'tow_truck',
#  'antenna',
#  'prune',
#  'teddy_bear',
#  'refrigerator',
#  'coconut',
#  'alarm_clock',
#  'wristband',
#  'cutting_tool',
#  'carton',
#  'underwear',
#  'parrot',
#  'lightning_rod',
#  'clock',
#  'ice_pack',
#  'mound',
#  'edible_corn',
#  'poker',
#  'beanie',
#  'truck',
#  'salmon',
#  'race_car',
#  'corset',
#  'recliner',
#  'egg_yolk',
#  'kilt',
#  'golf_club',
#  'tux',
#  'puffin',
#  'cabana',
#  'ladder',
#  'router',
#  'dress_hat',
#  'motorcycle',
#  'tape',
#  'tomato',
#  'clay_pottery_making',
#  'hearing_aid',
#  'place_mat',
#  'stepladder',
#  'coat_hanger',
#  'Lego',
#  'patty',
#  'trailer_truck',
#  'chap',
#  'domestic_ass',
#  'remote_control',
#  'chest_of_drawers',
#  'pad',
#  'carnation',
#  'wrench',
#  'blender',
#  'ginger',
#  'bun',
#  'camera_lens',
#  'vacuum_cleaner',
#  'paperback_book',
#  'snowboard',
#  'cork',
#  'pigeon',
#  'saucepan',
#  'measuring_stick',
#  'hose',
#  'legging',
#  'notepad',
#  'jewelry',
#  'hardback_book',
#  'alligator',
#  'eyepatch',
#  'brush_painting',
#  'prawn',
#  'water_bottle',
#  'kiwi_fruit',
#  'music_stool',
#  'beachball',
#  'locker',
#  'passport',
#  'dachshund',
#  'money',
#  'baseball',
#  'pen',
#  'stylus',
#  'butcher_knife',
#  'garbage',
#  'file',
#  'ballet_skirt',
#  'candle',
#  'railcar',
#  'wreath',
#  'chocolate_cake',
#  'curling_iron',
#  'cleaning_floor',
#  'jean',
#  'baseball_base',
#  'lanyard',
#  'freight_car',
#  'grizzly',
#  'pouch',
#  'pet',
#  'iron',
#  'cleansing_agent',
#  'shaver',
#  'knife',
#  'pool_table',
#  'projectile',
#  'grater',
#  'corkscrew',
#  'candy_cane',
#  'fedora',
#  'wine_bottle',
#  'sculpture',
#  'muffin',
#  'persimmon',
#  'milk',
#  'pencil_box',
#  'heron',
#  'dropper',
#  'footstool',
#  'trousers',
#  'quesadilla',
#  'rib',
#  'guitar',
#  'bartending',
#  'webcam',
#  'banana',
#  'cart',
#  'thermostat',
#  'chopping_wood',
#  'fudge',
#  'veil',
#  'Dutch_oven',
#  'corned_beef',
#  'carving_pumpkin',
#  'polar_bear',
#  'school_bus',
#  'paddle',
#  'apple_juice',
#  'icecream',
#  'scrambled_eggs',
#  'hog',
#  'playing_card',
#  'coffee_filter',
#  'tobacco_pipe',
#  'cargo_ship',
#  'turnip',
#  'sharpener',
#  'broom',
#  'cymbal',
#  'sunhat',
#  'dartboard',
#  'bending_back',
#  'egg_roll',
#  'hook',
#  'chicken',
#  'cone',
#  'bracelet',
#  'ironing_board',
#  'window_box',
#  'chain_mail',
#  'omelet',
#  'wheelchair',
#  'bobsledding',
#  'hammock',
#  'watch',
#  'iPod',
#  'lemonade',
#  'bandaging',
#  'monkey',
#  'frisbee',
#  'masher',
#  'pizza',
#  'cardigan',
#  'fleece',
#  'hair_dryer',
#  'gasmask',
#  'serving_dish',
#  'camel',
#  'yacht',
#  'futon',
#  'headstall',
#  'oil_lamp',
#  'steamer',
#  'broach',
#  'flowerpot',
#  'boxing_glove',
#  'bulletproof_vest',
#  'plate',
#  'playpen',
#  'parachute',
#  'oar',
#  'ambulance',
#  'toast',
#  'calf',
#  'sawhorse',
#  'toilet_tissue',
#  'barrel',
#  'turkey',
#  'platter',
#  'space_shuttle',
#  'pipe_bowl',
#  'shredder',
#  'bottle_opener',
#  'lamppost',
#  'crow',
#  'cider',
#  'fireplug',
#  'atomizer',
#  'sock',
#  'bath_mat',
#  'caviar',
#  'tree_house',
#  'basketball_backboard',
#  'blueberry',
#  'cherry',
#  'water_scooter',
#  'crayon',
#  'statue',
#  'vent',
#  'baguet',
#  'cooking_egg',
#  'funnel',
#  'piggy_bank',
#  'golfcart',
#  'root_beer',
#  'shark',
#  'cowbell',
#  'log',
#  'gravestone',
#  'slipper',
#  'shepherd_dog',
#  'home_plate',
#  'manhole',
#  'microscope',
#  'teacup',
#  'dagger',
#  'runner',
#  'headband',
#  'telephone_booth',
#  'barbell',
#  'butter',
#  'black_sheep',
#  'magazine',
#  'cheerleading',
#  'bead',
#  'bridal_gown',
#  'die',
#  'fork',
#  'hippopotamus',
#  'table',
#  'kitchen_sink',
#  'bobbin',
#  'underdrawers',
#  'breading_or_breadcrumbing',
#  'tricycle',
#  'nest',
#  'car_battery',
#  'hairbrush',
#  'cabin_car',
#  'clothespin',
#  'screwdriver',
#  'beetle',
#  'identity_card',
#  'phonograph_record',
#  'birdcage',
#  'hatbox',
#  'Christmas_tree',
#  'gravy_boat',
#  'building_cabinet',
#  'puppy',
#  'hairpin',
#  'nightshirt',
#  'packet',
#  'dispenser',
#  'surfboard',
#  'doing_nails',
#  'ball',
#  'matchbox',
#  'octopus',
#  'deadbolt',
#  'helmet',
#  'binder',
#  'hotplate',
#  'scarf',
#  'wall_clock',
#  'checking_tires',
#  'lasagna',
#  'gourd',
#  'trench_coat',
#  'blazer',
#  'inkpad',
#  'pepper_mill',
#  'shampoo',
#  'rat',
#  'cape',
#  'fishing_rod',
#  'tortilla',
#  'capoeira',
#  'bench_pressing',
#  'convertible',
#  'pie',
#  'cupcake',
#  'baby_waking_up',
#  'wedding_cake',
#  'diaper',
#  'changing_wheel',
#  'award',
#  'cube',
#  'shopping_cart',
#  'chinaware',
#  'artichoke',
#  'hot-air_balloon',
#  'earring',
#  'flamingo',
#  'sparkler',
#  'counting_money',
#  'thumbtack',
#  'tights',
#  'suit',
#  'automatic_washer',
#  'life_buoy',
#  'cistern',
#  'cruise_ship',
#  'pajamas',
#  'beatboxing',
#  'beret',
#  'tank_top',
#  'battery',
#  'streetlight',
#  'red_cabbage',
#  'gift_wrap',
#  'motor',
#  'onion',
#  'drinking',
#  'pineapple',
#  'sponge',
#  'blowing_out_candles',
#  'wig',
#  'armor',
#  'birdhouse',
#  'pliers',
#  'unicycle',
#  'thread',
#  'canoe',
#  'dog',
#  'apricot',
#  'broccoli',
#  'sleeping_bag',
#  'pickup_truck',
#  'puncher',
#  'almond',
#  'goldfish',
#  'yogurt',
#  'poster',
#  'baking_cookies',
#  'radiator',
#  'coaster',
#  'steering_wheel',
#  'figurine',
#  'salsa',
#  'trunk',
#  'candelabrum',
#  'chair',
#  'satchel',
#  'seedling',
#  'lampshade',
#  'tiara',
#  'pitcher',
#  'watering_can',
#  'manger',
#  'gargle',
#  'table-tennis_table',
#  'escargot',
#  'saddle_blanket',
#  'garbage_truck',
#  'dish',
#  'kitchen_table',
#  'camper',
#  'calculator',
#  'doorbell',
#  'pantyhose',
#  'plow',
#  'clutch_bag',
#  'cigarette_case',
#  'carbonated_water',
#  'sweatshirt',
#  'koala',
#  'sieve',
#  'bass_horn',
#  'hammer',
#  'bat',
#  'thermometer',
#  'pacifier',
#  'business_card',
#  'water_jug',
#  'pan',
#  'awning',
#  'wok',
#  'cookie',
#  'pickle',
#  'receipt',
#  'bending_metal',
#  'wolf',
#  'bee_keeping',
#  'celebrating',
#  'microwave_oven',
#  'bathtub',
#  'martini',
#  'bow',
#  'braiding_hair',
#  'raincoat',
#  'banjo',
#  'needle',
#  'heart',
#  'cab',
#  'hinge',
#  'cash_register',
#  'bolo_tie',
#  'scoreboard',
#  'softball',
#  'asparagus',
#  'booklet',
#  'signboard',
#  'hamper',
#  'bouquet',
#  'walking_stick',
#  'potholder',
#  'hockey_stick',
#  'mashed_potato',
#  'pocket_watch',
#  'truffle',
#  'urinal',
#  'climbing_a_rope',
#  'belt',
#  'roller_skate',
#  'answering_questions',
#  'cappuccino',
#  'printer',
#  'polo_shirt',
#  'knob',
#  'handbag',
#  'scrubbing_brush',
#  'bandage',
#  'teapot',
#  'beanbag',
#  'cookie_jar',
#  'fighter_jet',
#  'chickpea',
#  'rag_doll',
#  'harmonium',
#  'bucket',
#  'chicken_wire',
#  'reamer',
#  'syringe',
#  'mail_slot',
#  'taco',
#  'dollar',
#  'bagel',
#  'pitchfork',
#  'bear',
#  'violin',
#  'salami',
#  'barrow',
#  'romaine_lettuce',
#  'diary',
#  'tractor',
#  'abseiling',
#  'digging',
#  'paperclip',
#  'casserole',
#  'racket',
#  'checkerboard',
#  'clock_tower',
#  'ram',
#  'cutting_nails',
#  'tape_measure',
#  'blasting_sand',
#  'shaving_cream',
#  'flip-flop',
#  'ferret',
#  'parka',
#  'police_van',
#  'briefcase',
#  'sunglasses',
#  'tennis_racket',
#  'brownie',
#  'mailbox',
#  'timer',
#  'shaker',
#  'applying_cream',
#  'brussels_sprouts',
#  'glass',
#  'apron',
#  'seaplane',
#  'spectacles',
#  'grape',
#  'machine_gun',
#  'overalls',
#  'toy',
#  'hair_spray',
#  'hourglass',
#  'scarecrow',
#  'straw',
#  'dumpster',
#  'triangle',
#  'cooking_on_campfire',
#  'ring',
#  'telephone',
#  'bagpipe',
#  'jet_plane',
#  'CD_player',
#  'dinghy',
#  'globe',
#  'pony',
#  'bell_pepper',
#  'wick',
#  'parakeet',
#  'lamb-chop',
#  'sink',
#  'drawing',
#  'dishwasher_detergent',
#  'flashlight',
#  'gelatin',
#  'bandanna',
#  'stove',
#  'bookbinding',
#  'latch',
#  'burrito',
#  'grocery_bag',
#  'vending_machine',
#  'handcuff',
#  'toaster',
#  'cutting_watermelon',
#  'cufflink',
#  'chime',
#  'potato',
#  'boiled_egg',
#  'newsstand',
#  'button',
#  'dragonfly',
#  'tachometer',
#  'stapler',
#  'corkboard',
#  'pot',
#  'changing_oil',
#  'mandarin_orange',
#  'snowmobile',
#  'water_cooler',
#  'kite',
#  'cleaning_gutters',
#  'marker',
#  'baby',
#  'lab_coat',
#  'parking_meter',
#  'pepper',
#  'crawling_baby',
#  'eagle',
#  'knocker',
#  'dishrag',
#  'buoy',
#  'cover',
#  'bullhorn',
#  'falcon',
#  'saddlebag',
#  'cornmeal',
#  'steak',
#  'thimble',
#  'scraper',
#  'radio_receiver',
#  'phonebook',
#  'arm_wrestling',
#  'choker',
#  'windshield_wiper',
#  'tapestry',
#  'snake',
#  'lotion',
#  'fire_alarm',
#  'bottle',
#  'suitcase',
#  'peeler',
#  'pencil',
#  'doughnut',
#  'bedspread',
#  'safety_pin',
#  'lantern',
#  'cracking_neck',
#  'gondola',
#  'inhaler',
#  'toaster_oven',
#  'zucchini',
#  'flute_glass',
#  'crossbar',
#  'steak_knife',
#  'sweat_pants',
#  'ladybug',
#  'mask',
#  'cucumber',
#  'guacamole',
#  'teakettle',
#  'celery',
#  'passenger_ship',
#  'clasp',
#  'toolbox',
#  'canteen',
#  'clean_and_jerk',
#  'electric_chair',
#  'file_cabinet',
#  'tripod',
#  'mattress',
#  'bean_curd',
#  'tinsel',
#  'griddle',
#  'painting',
#  'wet_suit',
#  'bib',
#  'stockings',
#  'sportswear',
#  'radar',
#  'whipped_cream',
#  'blimp',
#  'drum',
#  'goose',
#  'milestone',
#  'sofa_bed',
#  'waffle',
#  'envelope',
#  'wooden_spoon',
#  'gazelle',
#  'air_drumming',
#  'hat',
#  'giant_panda',
#  'sandwich',
#  'fume_hood',
#  'coat',
#  'minivan',
#  'toothbrush',
#  'bench',
#  'zebra',
#  'duffel_bag',
#  'bonnet',
#  'bathrobe',
#  'coleslaw',
#  'tambourine',
#  'Band_Aid',
#  'sling',
#  'catching_or_throwing_frisbee',
#  'French_toast',
#  'toilet',
#  ...}

# %% [markdown]
# ### ConceptNet

# %%
# labels_set = set.union(labels_text_set, labels_audio_set, labels_video_set)
labels_set = set.union(labels_text_set, labels_video_set)

# %%
conceptnet = csv.reader(open('../data/kb/conceptnet-assertions-5.7.0.csv', 'r'), delimiter='\t')

concept_dict = defaultdict(set)

for i, row in enumerate(conceptnet):
        if i % 1000000 == 0:
            print("Processed {0} rows".format(i))
        
        lang1 = row[2].split("/")[2]
        lang2 = row[3].split("/")[2]
        if lang1 == 'en' and lang2 == 'en':
            c1 = row[2].split("/")[3]
            c2 = row[3].split("/")[3]
            weight = literal_eval(row[-1])["weight"]
            if c1 in labels_set:
                concept_dict[c1].add((c2, weight))
            if c2 in labels_set:
                concept_dict[c2].add((c1, weight))
# Out:
# Processed 0 rows
# Processed 1000000 rows
# Processed 2000000 rows
# Processed 3000000 rows
# Processed 4000000 rows
# Processed 5000000 rows
# Processed 6000000 rows
# Processed 7000000 rows
# Processed 8000000 rows
# Processed 9000000 rows
# Processed 10000000 rows
# Processed 11000000 rows
# Processed 12000000 rows
# Processed 13000000 rows
# Processed 14000000 rows
# Processed 15000000 rows
# Processed 16000000 rows
# Processed 17000000 rows
# Processed 18000000 rows
# Processed 19000000 rows
# Processed 20000000 rows
# Processed 21000000 rows
# Processed 22000000 rows
# Processed 23000000 rows
# Processed 24000000 rows
# Processed 25000000 rows
# Processed 26000000 rows
# Processed 27000000 rows
# Processed 28000000 rows
# Processed 29000000 rows
# Processed 30000000 rows
# Processed 31000000 rows
# Processed 32000000 rows
# Processed 33000000 rows
# Processed 34000000 rows

# %%
len(concept_dict)
# Out:
# 11565

# %%
from collections import Counter
cntr = Counter()
cntr.update([len(v) for k, v in concept_dict.items()])

# %%
cntr
# Out:
# Counter({50: 58,
#          24: 118,
#          15: 134,
#          101: 26,
#          41: 67,
#          178: 15,
#          132: 20,
#          111: 23,
#          152: 14,
#          349: 4,
#          374: 4,
#          127: 19,
#          88: 36,
#          473: 2,
#          126: 16,
#          199: 10,
#          83: 27,
#          333: 8,
#          143: 21,
#          176: 10,
#          238: 9,
#          52: 55,
#          197: 9,
#          164: 15,
#          81: 36,
#          328: 8,
#          187: 13,
#          134: 12,
#          432: 4,
#          184: 11,
#          273: 7,
#          45: 66,
#          58: 38,
#          138: 12,
#          173: 15,
#          48: 58,
#          38: 58,
#          461: 1,
#          272: 6,
#          248: 6,
#          148: 15,
#          87: 31,
#          42: 69,
#          284: 1,
#          56: 36,
#          359: 6,
#          26: 98,
#          216: 10,
#          91: 28,
#          656: 1,
#          956: 1,
#          222: 6,
#          121: 15,
#          320: 4,
#          123: 13,
#          519: 4,
#          902: 3,
#          494: 4,
#          215: 10,
#          1260: 1,
#          118: 26,
#          298: 7,
#          246: 6,
#          777: 1,
#          719: 1,
#          112: 22,
#          175: 20,
#          21: 128,
#          93: 25,
#          356: 3,
#          206: 10,
#          214: 8,
#          447: 4,
#          563: 3,
#          49: 63,
#          263: 9,
#          343: 6,
#          29: 125,
#          75: 40,
#          116: 25,
#          79: 30,
#          213: 11,
#          644: 2,
#          316: 7,
#          1197: 1,
#          727: 2,
#          416: 2,
#          204: 5,
#          311: 6,
#          89: 29,
#          325: 4,
#          329: 6,
#          166: 15,
#          181: 11,
#          136: 12,
#          74: 30,
#          195: 15,
#          169: 9,
#          300: 4,
#          336: 5,
#          47: 44,
#          17: 157,
#          225: 12,
#          76: 27,
#          422: 5,
#          495: 3,
#          62: 39,
#          419: 4,
#          85: 25,
#          30: 97,
#          254: 9,
#          253: 9,
#          277: 7,
#          135: 16,
#          78: 33,
#          10: 171,
#          19: 151,
#          25: 104,
#          227: 9,
#          105: 22,
#          122: 19,
#          592: 4,
#          170: 13,
#          475: 2,
#          157: 20,
#          139: 6,
#          545: 3,
#          392: 3,
#          1933: 1,
#          1016: 1,
#          523: 4,
#          44: 64,
#          381: 6,
#          35: 84,
#          165: 13,
#          358: 6,
#          188: 8,
#          113: 22,
#          43: 65,
#          71: 48,
#          342: 4,
#          351: 4,
#          167: 10,
#          63: 45,
#          182: 14,
#          1008: 1,
#          1137: 2,
#          1134: 1,
#          900: 1,
#          1063: 1,
#          186: 9,
#          2707: 1,
#          102: 27,
#          624: 3,
#          335: 5,
#          161: 11,
#          202: 9,
#          515: 2,
#          252: 3,
#          108: 23,
#          66: 35,
#          61: 40,
#          569: 2,
#          64: 35,
#          28: 95,
#          305: 3,
#          120: 21,
#          117: 22,
#          151: 14,
#          156: 17,
#          55: 50,
#          2931: 1,
#          331: 7,
#          464: 5,
#          34: 66,
#          92: 29,
#          278: 3,
#          704: 1,
#          90: 26,
#          65: 33,
#          191: 9,
#          125: 15,
#          129: 20,
#          244: 10,
#          12: 157,
#          505: 4,
#          69: 36,
#          955: 2,
#          436: 4,
#          259: 9,
#          198: 11,
#          145: 12,
#          380: 4,
#          279: 2,
#          249: 5,
#          2299: 1,
#          3533: 1,
#          1154: 1,
#          5628: 1,
#          10050: 1,
#          5687: 1,
#          507: 5,
#          189: 17,
#          430: 1,
#          231: 8,
#          107: 27,
#          172: 11,
#          77: 39,
#          234: 2,
#          159: 19,
#          708: 1,
#          290: 6,
#          406: 2,
#          393: 3,
#          20: 151,
#          32: 82,
#          633: 2,
#          281: 8,
#          68: 38,
#          183: 9,
#          424: 3,
#          203: 7,
#          80: 26,
#          84: 31,
#          462: 2,
#          651: 2,
#          185: 9,
#          327: 2,
#          1372: 1,
#          60: 47,
#          326: 7,
#          103: 24,
#          230: 11,
#          155: 19,
#          407: 5,
#          418: 3,
#          772: 2,
#          291: 1,
#          240: 7,
#          497: 2,
#          73: 31,
#          97: 27,
#          99: 25,
#          59: 42,
#          648: 3,
#          622: 1,
#          317: 7,
#          266: 6,
#          979: 2,
#          219: 7,
#          109: 16,
#          752: 1,
#          572: 1,
#          738: 3,
#          149: 16,
#          674: 4,
#          404: 4,
#          46: 59,
#          190: 14,
#          146: 14,
#          265: 10,
#          94: 29,
#          67: 34,
#          1068: 1,
#          733: 1,
#          893: 1,
#          37: 66,
#          303: 4,
#          425: 2,
#          31: 86,
#          235: 11,
#          286: 6,
#          208: 14,
#          86: 24,
#          27: 99,
#          1067: 1,
#          114: 19,
#          637: 3,
#          130: 22,
#          909: 1,
#          334: 3,
#          137: 23,
#          100: 22,
#          115: 22,
#          269: 8,
#          142: 15,
#          243: 7,
#          162: 16,
#          154: 17,
#          818: 3,
#          36: 88,
#          40: 64,
#          260: 10,
#          96: 17,
#          924: 2,
#          1060: 1,
#          388: 3,
#          70: 40,
#          332: 6,
#          513: 4,
#          321: 5,
#          128: 21,
#          229: 9,
#          594: 2,
#          736: 1,
#          250: 10,
#          211: 5,
#          192: 10,
#          217: 10,
#          694: 1,
#          365: 5,
#          270: 4,
#          292: 5,
#          1147: 1,
#          571: 1,
#          13: 159,
#          193: 11,
#          7: 220,
#          168: 14,
#          907: 1,
#          1153: 1,
#          72: 34,
#          712: 1,
#          1141: 1,
#          366: 1,
#          931: 2,
#          1230: 1,
#          543: 3,
#          33: 77,
#          301: 5,
#          768: 2,
#          233: 6,
#          144: 14,
#          354: 3,
#          460: 3,
#          405: 5,
#          340: 3,
#          124: 14,
#          207: 8,
#          309: 6,
#          1089: 2,
#          579: 1,
#          307: 3,
#          224: 9,
#          396: 5,
#          862: 1,
#          196: 5,
#          22: 122,
#          179: 9,
#          577: 2,
#          433: 1,
#          147: 16,
#          131: 20,
#          212: 9,
#          2123: 1,
#          368: 4,
#          445: 1,
#          849: 1,
#          686: 2,
#          382: 3,
#          665: 1,
#          2902: 1,
#          607: 4,
#          785: 1,
#          508: 5,
#          95: 22,
#          451: 3,
#          630: 2,
#          596: 1,
#          1599: 1,
#          271: 6,
#          194: 14,
#          413: 5,
#          716: 1,
#          784: 2,
#          352: 4,
#          715: 1,
#          580: 5,
#          511: 2,
#          627: 2,
#          689: 3,
#          540: 1,
#          481: 1,
#          174: 7,
#          920: 1,
#          826: 1,
#          1200: 1,
#          1045: 1,
#          1669: 1,
#          1675: 1,
#          575: 1,
#          262: 11,
#          501: 4,
#          287: 4,
#          1462: 1,
#          1077: 1,
#          1216: 1,
#          1884: 1,
#          431: 2,
#          205: 8,
#          593: 1,
#          236: 5,
#          18: 137,
#          375: 5,
#          367: 2,
#          347: 6,
#          310: 9,
#          986: 1,
#          538: 4,
#          493: 2,
#          456: 4,
#          104: 37,
#          177: 12,
#          747: 2,
#          357: 11,
#          429: 4,
#          817: 1,
#          304: 5,
#          757: 3,
#          775: 1,
#          819: 1,
#          268: 7,
#          522: 2,
#          360: 3,
#          256: 8,
#          209: 10,
#          1768: 1,
#          276: 6,
#          201: 8,
#          1902: 1,
#          598: 1,
#          439: 3,
#          133: 22,
#          54: 38,
#          228: 9,
#          274: 8,
#          346: 4,
#          293: 5,
#          600: 1,
#          1378: 1,
#          531: 1,
#          576: 2,
#          378: 2,
#          574: 3,
#          1404: 1,
#          568: 2,
#          1306: 1,
#          306: 5,
#          410: 5,
#          110: 23,
#          302: 4,
#          11: 181,
#          978: 2,
#          477: 2,
#          258: 7,
#          226: 8,
#          294: 5,
#          626: 2,
#          929: 1,
#          180: 14,
#          370: 2,
#          472: 3,
#          678: 1,
#          806: 1,
#          1118: 1,
#          308: 5,
#          1222: 1,
#          322: 3,
#          289: 7,
#          529: 2,
#          892: 1,
#          295: 3,
#          1184: 1,
#          153: 16,
#          567: 1,
#          369: 3,
#          372: 4,
#          847: 1,
#          1324: 1,
#          9: 185,
#          467: 4,
#          449: 6,
#          2094: 1,
#          1555: 1,
#          377: 2,
#          660: 3,
#          6: 229,
#          158: 14,
#          813: 1,
#          82: 28,
#          221: 7,
#          257: 4,
#          446: 1,
#          408: 4,
#          1285: 1,
#          232: 7,
#          919: 1,
#          415: 4,
#          756: 1,
#          476: 3,
#          171: 9,
#          8: 188,
#          345: 3,
#          808: 3,
#          242: 4,
#          492: 2,
#          398: 3,
#          455: 2,
#          843: 1,
#          264: 2,
#          786: 2,
#          739: 1,
#          623: 2,
#          394: 4,
#          371: 6,
#          14: 140,
#          106: 21,
#          2393: 1,
#          1538: 1,
#          811: 1,
#          1567: 1,
#          141: 18,
#          625: 3,
#          1071: 1,
#          612: 2,
#          512: 3,
#          57: 39,
#          98: 16,
#          267: 4,
#          480: 3,
#          220: 4,
#          496: 3,
#          850: 1,
#          518: 1,
#          654: 2,
#          549: 2,
#          452: 4,
#          39: 64,
#          732: 1,
#          330: 3,
#          551: 1,
#          985: 1,
#          448: 2,
#          400: 2,
#          51: 40,
#          618: 1,
#          163: 5,
#          218: 6,
#          275: 2,
#          503: 3,
#          458: 1,
#          484: 1,
#          1206: 1,
#          350: 4,
#          386: 2,
#          361: 3,
#          312: 3,
#          880: 1,
#          337: 5,
#          324: 7,
#          438: 1,
#          729: 1,
#          3143: 1,
#          160: 14,
#          435: 6,
#          724: 1,
#          383: 2,
#          223: 4,
#          140: 16,
#          700: 1,
#          586: 2,
#          1489: 1,
#          587: 2,
#          1545: 1,
#          781: 1,
#          313: 3,
#          662: 1,
#          1181: 2,
#          628: 1,
#          16: 136,
#          614: 1,
#          443: 1,
#          341: 4,
#          2957: 1,
#          390: 3,
#          53: 42,
#          1111: 2,
#          119: 24,
#          339: 3,
#          1316: 1,
#          1259: 1,
#          239: 8,
#          314: 4,
#          210: 8,
#          315: 7,
#          1617: 1,
#          746: 1,
#          1830: 1,
#          457: 1,
#          200: 10,
#          463: 1,
#          542: 1,
#          731: 2,
#          830: 2,
#          578: 1,
#          373: 5,
#          150: 17,
#          384: 3,
#          261: 5,
#          710: 1,
#          615: 3,
#          972: 1,
#          565: 1,
#          245: 4,
#          796: 1,
#          927: 1,
#          683: 1,
#          788: 2,
#          23: 86,
#          355: 3,
#          690: 1,
#          1252: 1,
#          450: 3,
#          650: 1,
#          241: 3,
#          718: 1,
#          470: 2,
#          459: 1,
#          791: 1,
#          414: 3,
#          247: 4,
#          319: 2,
#          1009: 1,
#          552: 1,
#          1120: 1,
#          395: 2,
#          237: 4,
#          491: 1,
#          619: 1,
#          953: 1,
#          971: 1,
#          911: 1,
#          285: 4,
#          376: 3,
#          391: 3,
#          876: 1,
#          548: 2,
#          1512: 1,
#          805: 1,
#          861: 1,
#          921: 1,
#          399: 4,
#          490: 1,
#          679: 1,
#          582: 1,
#          1000: 1,
#          296: 6,
#          1763: 1,
#          603: 4,
#          251: 4,
#          421: 2,
#          283: 4,
#          717: 1,
#          397: 4,
#          2: 347,
#          938: 1,
#          534: 1,
#          468: 3,
#          1006: 1,
#          409: 3,
#          1837: 1,
#          1243: 1,
#          977: 2,
#          1022: 1,
#          1078: 1,
#          530: 3,
#          941: 1,
#          987: 1,
#          680: 1,
#          597: 1,
#          1043: 1,
#          960: 1,
#          1475: 1,
#          744: 1,
#          280: 5,
#          610: 1,
#          869: 1,
#          444: 3,
#          995: 1,
#          299: 2,
#          1258: 1,
#          1304: 1,
#          516: 2,
#          485: 1,
#          6007: 1,
#          401: 2,
#          486: 2,
#          779: 3,
#          635: 1,
#          3789: 1,
#          889: 2,
#          411: 3,
#          1778: 1,
#          344: 2,
#          489: 2,
#          434: 2,
#          725: 3,
#          599: 2,
#          533: 2,
#          638: 1,
#          1729: 1,
#          841: 1,
#          362: 1,
#          453: 2,
#          323: 4,
#          544: 3,
#          730: 2,
#          968: 1,
#          288: 2,
#          442: 1,
#          631: 2,
#          7502: 1,
#          487: 1,
#          758: 4,
#          714: 2,
#          1101: 1,
#          948: 1,
#          483: 2,
#          741: 1,
#          441: 2,
#          1336: 1,
#          4037: 1,
#          761: 1,
#          866: 1,
#          595: 2,
#          499: 2,
#          617: 1,
#          1323: 1,
#          1160: 1,
#          412: 2,
#          1031: 1,
#          4: 268,
#          1115: 1,
#          865: 1,
#          363: 2,
#          2022: 1,
#          1117: 1,
#          1041: 1,
#          707: 1,
#          4462: 1,
#          1027: 1,
#          403: 3,
#          967: 1,
#          583: 1,
#          479: 4,
#          1086: 1,
#          666: 1,
#          506: 1,
#          417: 3,
#          973: 1,
#          488: 2,
#          389: 2,
#          589: 3,
#          1057: 1,
#          402: 1,
#          348: 2,
#          1032: 1,
#          1430: 1,
#          925: 1,
#          338: 4,
#          1123: 1,
#          318: 3,
#          426: 3,
#          255: 4,
#          541: 2,
#          562: 1,
#          737: 1,
#          1442: 1,
#          555: 1,
#          636: 1,
#          692: 1,
#          1128: 1,
#          673: 1,
#          702: 1,
#          440: 2,
#          836: 1,
#          728: 1,
#          3: 274,
#          5: 220,
#          1052: 1,
#          887: 1,
#          556: 1,
#          608: 1,
#          858: 1,
#          835: 1,
#          1613: 1,
#          2041: 1,
#          564: 1,
#          748: 1,
#          2198: 1,
#          520: 2,
#          629: 2,
#          585: 2,
#          859: 1,
#          735: 1,
#          466: 2,
#          7350: 1,
#          875: 1,
#          498: 1,
#          1038: 1,
#          1355: 1,
#          428: 2,
#          914: 1,
#          749: 1,
#          2797: 1,
#          528: 1,
#          3775: 1,
#          682: 1,
#          740: 1,
#          699: 1,
#          4508: 1,
#          1483: 1,
#          387: 2,
#          3102: 1,
#          640: 1,
#          2197: 1,
#          1528: 1,
#          1106: 1,
#          566: 1,
#          353: 1,
#          661: 1,
#          1094: 1,
#          754: 1,
#          1217: 1,
#          482: 1,
#          688: 1,
#          526: 1,
#          778: 1,
#          471: 1,
#          829: 1,
#          657: 1,
#          770: 1,
#          823: 1,
#          1056: 1,
#          867: 1,
#          750: 1,
#          734: 2,
#          514: 2,
#          550: 1,
#          561: 1,
#          605: 1,
#          1554: 1,
#          1: 468,
#          753: 1,
#          525: 1,
#          812: 1,
#          437: 1,
#          364: 1,
#          1339: 1,
#          4335: 1,
#          6511: 1,
#          1938: 1,
#          1895: 1,
#          3012: 1,
#          1428: 1,
#          1650: 1,
#          379: 2,
#          2277: 1,
#          751: 1,
#          1335: 1,
#          5394: 1,
#          646: 1,
#          2365: 1,
#          2467: 1,
#          1819: 1,
#          897: 1,
#          632: 1,
#          1069: 1,
#          643: 1,
#          546: 1,
#          1393: 1,
#          1485: 1,
#          504: 1})

# %%
from nltk.corpus import stopwords
from spacy.lang.en.stop_words import STOP_WORDS as spacy_stopwords
nltk_stopwords = stopwords.words('english')
# spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS # older version of spacy
stopwords = set(nltk_stopwords).union(spacy_stopwords)

# %%
filtered_conceptnet = {}
for key_concept in concept_dict:
    if key_concept in labels_set and key_concept not in stopwords:
        filtered_conceptnet[key_concept] = set()
        for connect_concept, connect_weight in concept_dict[key_concept]:
            if connect_concept not in stopwords:
                filtered_conceptnet[key_concept].add((connect_concept, connect_weight))

# %%
len(filtered_conceptnet)
# Out:
# 11276

# %%
cntr2 = Counter()
cntr2.update([len(v) for k, v in filtered_conceptnet.items()])

# %%
for k, v in filtered_conceptnet.items():
    if len(v) > 300:
        print(k, len(v))
# Out:
# gain 335
# join 362
# ability 468
# normal 331
# fix 320
# present 407
# leave 445
# purpose 348
# acid 655
# base 941
# peace 310
# act 877
# real 320
# action 1239
# activity 768
# rest 694
# future 338
# remove 557
# speaker 337
# biological 644
# birth 313
# child 1180
# children 721
# adult 308
# childish 325
# advance 317
# marriage 420
# relationship 492
# negative 410
# stop 576
# away 425
# age 528
# grow 385
# human 1919
# number 955
# old 517
# young 379
# agent 544
# patient 357
# defeat 328
# agreement 351
# air 991
# earth 1121
# fire 1127
# ground 877
# land 1055
# water 2699
# window 611
# alcoholic 335
# dead 507
# free 560
# crowd 499
# people 2912
# short 453
# red 699
# analysis 505
# order 943
# ancient 427
# new 346
# anger 376
# animal 2281
# bird 3529
# man 1142
# mineral 5626
# person 9992
# plant 5674
# vegetable 505
# separate 423
# problem 406
# question 369
# wrong 322
# post 624
# low 411
# pattern 458
# sense 340
# social 646
# specific 323
# house 1364
# hide 389
# appearance 409
# apple 758
# religious 646
# fall 608
# lay 304
# lie 436
# set 970
# sleep 741
# arm 561
# leg 722
# clothing 672
# army 400
# bow 404
# art 1053
# logic 725
# science 888
# artificial 302
# natural 434
# atom 1056
# attack 623
# position 878
# fail 326
# stick 805
# spring 490
# home 1033
# stay 320
# team 380
# cool 330
# baby 504
# forward 312
# current 628
# toe 312
# bad 587
# good 721
# right 675
# true 327
# ball 1138
# square 563
# egg 896
# band 1144
# hang 348
# bank 698
# bar 1126
# church 817
# cover 903
# plate 1207
# bat 765
# battle 351
# friend 456
# speak 337
# bear 628
# beauty 302
# bed 1062
# chair 450
# floor 565
# furniture 306
# living 393
# room 850
# bell 574
# beverage 364
# food 2116
# thing 353
# big 440
# little 333
# small 833
# bill 668
# check 379
# coin 660
# fish 2897
# plane 607
# death 781
# birthday 484
# date 435
# day 620
# die 587
# happy 354
# night 333
# time 1546
# bit 505
# sweet 410
# black 711
# white 782
# bright 345
# colour 713
# handle 571
# block 510
# blow 582
# blue 622
# green 685
# sky 527
# yellow 478
# board 907
# boat 825
# car 1192
# ship 1038
# body 1636
# head 1654
# mind 567
# spirit 501
# bone 1449
# muscle 1074
# skin 1215
# book 1869
# magazine 430
# interest 491
# fun 592
# carry 362
# employee 365
# bottle 341
# bound 310
# box 971
# circle 530
# boy 482
# girl 447
# branch 739
# center 351
# stem 427
# bread 806
# butter 303
# meat 756
# wine 774
# break 800
# piece 506
# work 1743
# hold 498
# breast 357
# internet 1896
# bridge 719
# long 591
# dark 436
# thin 346
# destroy 372
# cow 596
# female 1372
# bullet 521
# gun 570
# shot 374
# burn 563
# business 1396
# pleasure 402
# moth 568
# buy 411
# money 1297
# sell 301
# sale 404
# cable 309
# cake 961
# cream 303
# ice 475
# text 625
# rough 347
# school 923
# jar 364
# cancer 472
# cap 324
# capital 665
# case 796
# town 1116
# captain 525
# deck 305
# hand 1193
# mate 316
# truck 331
# flat 525
# card 875
# paper 1171
# care 546
# mean 410
# term 553
# cast 366
# castle 352
# cat 842
# dog 1319
# catch 354
# drop 727
# cause 451
# effect 442
# cell 2083
# line 1541
# dollar 362
# edge 643
# stand 349
# table 799
# community 445
# skill 408
# change 1262
# character 912
# characteristic 413
# charge 749
# pay 462
# deal 333
# fair 349
# cheese 538
# chick 342
# chicken 794
# duck 484
# turkey 327
# indian 397
# mother 450
# father 325
# china 834
# force 774
# note 728
# single 607
# christian 522
# christmas 386
# summer 366
# subject 479
# city 2385
# country 1527
# farm 799
# forest 434
# state 1548
# village 576
# talk 613
# class 1052
# student 612
# clay 331
# clean 508
# clear 493
# solid 623
# climb 442
# close 396
# open 468
# pen 306
# closet 352
# opening 339
# clothes 370
# cloud 652
# rain 493
# sun 841
# club 511
# heart 652
# fluid 549
# fine 406
# coast 443
# sea 727
# coffee 327
# cold 549
# heat 972
# hot 446
# colony 392
# shade 604
# common 441
# communication 481
# spread 334
# company 1183
# pair 342
# son 382
# competition 370
# complete 337
# complex 543
# simple 308
# condition 860
# pull 330
# waste 556
# construction 578
# support 765
# continent 319
# asia 438
# island 726
# ocean 486
# british 3128
# contract 414
# increase 427
# control 714
# copy 371
# paste 352
# corn 627
# seed 923
# corner 317
# wall 727
# cost 336
# dress 745
# cotton 691
# silk 583
# wool 633
# count 330
# metal 1476
# course 578
# smooth 380
# horse 1536
# walk 760
# creature 308
# picture 504
# cross 654
# group 1171
# individual 442
# crown 616
# cry 596
# laugh 439
# smile 336
# disease 2952
# news 558
# print 620
# curve 389
# cut 1092
# seal 342
# damage 337
# dance 1302
# flower 1254
# sing 314
# danger 310
# light 1614
# life 734
# live 485
# salt 1827
# debt 322
# profit 444
# think 456
# high 533
# offensive 730
# degree 793
# level 565
# supply 341
# department 361
# depression 387
# desert 376
# design 574
# desk 571
# love 700
# raise 368
# development 459
# god 959
# difficult 347
# direct 315
# round 555
# strength 376
# health 413
# information 794
# like 879
# disorder 683
# male 783
# distance 581
# union 351
# doctor 683
# fiction 309
# computer 1249
# doll 408
# figure 436
# soldier 650
# wild 303
# door 676
# road 704
# double 466
# draw 587
# paint 943
# painting 513
# dream 461
# suit 323
# strip 324
# drink 1069
# dry 454
# eat 783
# eating 413
# throw 365
# drive 795
# park 446
# ride 348
# walking 311
# lift 363
# rise 362
# wet 305
# jump 317
# weak 354
# duty 312
# function 1001
# ear 545
# nose 661
# heaven 330
# space 1093
# hard 465
# fast 391
# flow 617
# middle 414
# effort 309
# electric 324
# steam 485
# electronics 686
# end 602
# energy 945
# mass 801
# matter 453
# equal 493
# record 892
# escape 312
# evil 374
# performance 387
# rule 753
# exchange 363
# relax 336
# exercise 863
# potato 370
# surprise 528
# experience 369
# express 398
# local 319
# eye 1487
# mouth 794
# face 837
# foot 905
# fact 320
# belief 399
# false 329
# opinion 390
# voice 483
# factory 307
# pass 648
# knowledge 582
# fly 985
# season 305
# family 1754
# fan 601
# plain 337
# farmer 419
# fashion 381
# fat 495
# fear 713
# feed 367
# feeling 394
# feet 427
# lady 390
# field 933
# fight 525
# making 466
# cup 343
# cavity 372
# finger 990
# soft 406
# mammal 1835
# woman 1239
# fit 387
# movement 1015
# flash 377
# strong 365
# roof 427
# bee 402
# swim 445
# fold 328
# lead 1060
# leader 395
# fool 310
# american 729
# native 522
# game 1161
# remember 317
# knife 448
# form 926
# formal 598
# argument 396
# frequency 321
# period 574
# fruit 986
# organic 615
# reduce 414
# weight 674
# garden 585
# gas 968
# liquid 1040
# general 435
# heavy 398
# glass 944
# plastic 432
# wood 1466
# study 742
# gold 602
# silver 866
# goods 442
# regular 316
# government 991
# great 361
# growth 503
# hammer 356
# software 1250
# help 398
# desire 351
# neck 565
# tail 567
# point 1281
# wound 470
# illness 586
# trouble 368
# public 512
# way 469
# historical 5999
# history 682
# hit 394
# job 484
# office 766
# street 626
# minute 302
# goal 384
# idea 462
# watch 497
# legal 3774
# read 502
# material 884
# important 332
# attention 363
# preserve 304
# security 351
# intelligence 314
# stupid 411
# iron 1774
# jack 342
# speech 485
# judge 671
# criminal 434
# shoot 368
# punch 353
# kill 715
# king 596
# queen 311
# lord 389
# lake 531
# large 632
# medium 318
# law 1724
# leaf 898
# learn 428
# learning 414
# length 352
# letter 818
# library 427
# store 584
# statement 351
# thunder 440
# limit 398
# lip 357
# list 448
# listen 321
# load 320
# lock 394
# strike 412
# look 398
# servant 534
# war 723
# machine 963
# master 467
# maker 350
# manner 428
# march 317
# mark 626
# volume 371
# match 376
# medicine 7495
# poison 459
# member 478
# memory 524
# men 301
# humans 435
# stone 919
# milk 710
# rock 1095
# positive 353
# title 364
# use 638
# fungus 947
# mole 450
# month 347
# year 464
# moon 731
# motion 618
# movie 433
# play 1311
# killing 336
# music 4017
# noise 496
# television 760
# address 385
# napkin 337
# cloth 591
# nation 435
# nature 491
# nest 605
# sports 1312
# newspaper 429
# tone 315
# word 1149
# smell 384
# object 766
# official 412
# oil 1019
# rent 304
# carbon 1112
# page 476
# pain 858
# pan 360
# pot 498
# tree 2016
# building 1110
# party 1026
# meeting 339
# antibiotic 706
# philosopher 356
# physical 752
# mental 386
# physics 4456
# place 971
# plan 397
# wing 506
# bowl 323
# musical 306
# pole 374
# polish 473
# port 338
# power 956
# practice 576
# theory 518
# president 329
# press 344
# price 589
# write 476
# writing 1073
# math 665
# solution 506
# produce 412
# product 967
# service 599
# production 404
# property 818
# protect 324
# protest 487
# scientist 548
# punishment 439
# teacher 407
# quality 960
# taste 480
# rabbit 424
# fox 386
# turtle 392
# snow 886
# singing 354
# reading 578
# reason 318
# track 399
# stress 383
# religion 1055
# buying 410
# restaurant 399
# result 338
# return 353
# rice 513
# ring 1021
# river 1415
# stream 348
# sand 652
# roll 550
# roman 310
# kitchen 360
# rub 312
# run 903
# running 345
# rush 326
# sail 470
# sugar 1119
# college 411
# arts 349
# seat 494
# section 304
# series 471
# spot 314
# shake 411
# shape 584
# sheep 750
# sheet 375
# shock 501
# shoe 537
# hat 343
# sock 323
# angle 415
# signal 540
# source 324
# size 554
# slip 484
# touch 530
# smoke 725
# sneeze 318
# soap 512
# drunk 316
# song 618
# sound 1419
# soup 546
# squirrel 619
# stage 644
# screen 356
# standard 434
# statue 373
# steel 677
# step 464
# stitch 494
# story 511
# stretch 438
# structure 1127
# tax 667
# symptom 389
# wear 303
# tap 315
# test 603
# thinking 326
# tin 590
# aluminum 698
# frog 302
# trade 435
# traditional 529
# travel 823
# treat 301
# trick 444
# bush 323
# turn 693
# driving 411
# bend 309
# unit 1030
# user 392
# value 864
# vein 472
# view 440
# model 423
# phone 316
# wax 716
# wash 544
# clock 415
# wave 757
# particle 606
# weather 611
# hair 852
# wind 823
# beer 456
# cabinet 441
# india 1609
# vehicle 756
# canada 2036
# stomach 416
# tube 451
# actor 387
# theatre 313
# mail 318
# mexico 373
# london 404
# russia 562
# pocket 315
# texas 902
# aircraft 729
# alcohol 748
# universe 307
# greece 412
# england 2194
# bug 304
# pool 369
# ant 351
# container 486
# indiana 518
# bible 335
# florida 368
# yard 413
# market 626
# shop 631
# university 451
# coat 575
# hospital 373
# planet 539
# atmosphere 350
# molecule 856
# court 729
# photograph 314
# bacteria 504
# bag 464
# train 487
# protection 305
# washington 328
# world 525
# hole 628
# sport 868
# wheel 495
# bark 339
# baseball 1022
# basketball 368
# toilet 305
# beam 454
# photo 312
# bicycle 332
# bishop 380
# blood 1350
# bomb 341
# boot 365
# map 407
# society 427
# brain 914
# california 747
# mouse 445
# canal 334
# military 2784
# telephone 361
# africa 528
# cattle 334
# channel 406
# philippines 503
# chess 360
# county 331
# crab 462
# circuit 332
# engine 373
# collection 405
# network 519
# usa 3773
# cook 509
# cooking 680
# fabric 738
# region 597
# nebraska 355
# tennessee 309
# culture 697
# data 587
# frame 449
# dish 605
# dna 435
# file 401
# needle 312
# drug 4508
# education 777
# electricity 483
# entertainment 409
# equipment 301
# station 348
# feature 379
# film 1475
# fishing 477
# flag 469
# football 395
# fuel 323
# fur 314
# garment 386
# german 364
# grape 436
# mathematics 3088
# program 628
# joint 638
# hook 421
# horn 401
# thought 381
# hydrogen 2197
# industry 322
# injury 434
# insect 1525
# instrument 1103
# key 543
# leather 422
# display 326
# radio 564
# account 460
# literature 542
# lizard 357
# meal 378
# meaning 332
# message 307
# substance 736
# monkey 352
# moss 400
# motor 335
# grain 590
# jaw 320
# musical_instrument 660
# musician 358
# nerve 512
# organism 1093
# tongue 407
# nucleus 381
# organ 753
# system 1215
# passage 335
# path 341
# penis 488
# pig 479
# pigeon 333
# pipe 450
# area 680
# location 349
# toy 561
# police 391
# beat 516
# soil 549
# programming 776
# weapon 777
# rail 404
# report 303
# rose 309
# rubber 302
# sauce 403
# scale 753
# technology 470
# score 346
# sex 823
# shark 360
# shell 653
# sign 757
# snake 536
# sponge 316
# star 820
# steroid 1136
# storage 328
# string 471
# surface 1048
# sword 326
# thread 348
# tissue 867
# tool 749
# cricket 715
# province 504
# urine 404
# vine 425
# virus 514
# french 550
# worm 431
# academic 307
# kiss 339
# pitch 558
# target 315
# race 594
# chinese 732
# communicate 322
# device 1551
# dye 393
# element 804
# emotion 431
# event 1104
# share 320
# image 752
# italian 325
# japanese 524
# method 307
# officer 411
# phrase 337
# pressure 591
# principle 393
# process 977
# type 804
# situation 515
# speed 403
# stock 472
# style 512
# temperature 623
# spin 317
# treatment 436
# holiday 331
# celebrating 343
# expression 448
# performing 308
# stroke 360
# infection 595
# bond 375
# transfer 388
# loop 311
# perform 328
# environment 470
# poker 343
# surgery 1339
# biology 4332
# chemistry 6507
# electron 350
# engineering 582
# english 715
# geology 1937
# golf 341
# linguistics 1892
# pathology 3012
# philosophy 1421
# enzyme 1649
# phase 321
# chemical 714
# hormone 379
# greek 428
# medical 615
# nautical 2266
# african 435
# european 499
# genetic 426
# technique 439
# topology 314
# gene 479
# reaction 649
# sexual 750
# species 1335
# nickel 329
# aluminium 306
# anatomy 5393
# surgical 344
# brown 331
# authority 464
# carbohydrate 674
# circular 305
# distribution 323
# inflammation 646
# language 2357
# neuron 324
# policy 308
# psychology 787
# scientific 332
# site 355
# protein 2466
# berry 333
# application 373
# sequence 457
# astronomy 1818
# australian 310
# code 335
# axis 406
# formation 396
# beetle 379
# covering 325
# pin 336
# rate 436
# component 437
# matrix 313
# electrical 479
# measure 882
# pharmacology 382
# physiology 632
# irish 313
# calcium 1067
# direction 500
# representation 356
# operation 631
# titanium 304
# document 543
# entomology 349
# grammar 1385
# mythology 428
# humorous 1483
# issue 351
# au 500
# hinduism 396

# %%
cntr2.most_common(50)
# Out:
# [(1, 473),
#  (2, 348),
#  (3, 281),
#  (4, 270),
#  (6, 243),
#  (5, 216),
#  (7, 215),
#  (9, 187),
#  (8, 185),
#  (11, 182),
#  (10, 181),
#  (17, 156),
#  (12, 155),
#  (20, 152),
#  (13, 150),
#  (16, 147),
#  (18, 139),
#  (15, 137),
#  (14, 134),
#  (21, 132),
#  (19, 128),
#  (29, 122),
#  (24, 119),
#  (22, 117),
#  (27, 109),
#  (26, 98),
#  (25, 96),
#  (35, 91),
#  (30, 90),
#  (23, 90),
#  (28, 88),
#  (33, 80),
#  (31, 77),
#  (45, 75),
#  (32, 74),
#  (36, 71),
#  (43, 70),
#  (40, 69),
#  (38, 67),
#  (34, 66),
#  (41, 64),
#  (48, 63),
#  (37, 63),
#  (39, 63),
#  (49, 57),
#  (42, 55),
#  (44, 55),
#  (46, 52),
#  (50, 50),
#  (71, 48)]

# %%
filtered_conceptnet['football']
# Out:
# {('11', 1.0),
#  ('ba', 1.0),
#  ('ball', 1.0),
#  ('ball', 2.0),
#  ('bent', 1.0),
#  ('bladder', 1.0),
#  ('bladder', 2.0),
#  ('boot', 1.0),
#  ('canada', 1.0),
#  ('casual', 1.0),
#  ('center', 2.0),
#  ('complete', 2.0),
#  ('completed', 2.0),
#  ('corner', 1.0),
#  ('cross', 1.0),
#  ('crowd', 1.015),
#  ('dresser', 1.0),
#  ('end', 2.0),
#  ('foot', 1.0),
#  ('forward', 1.0),
#  ('fun', 1.0),
#  ('game', 1.0),
#  ('game', 1.672),
#  ('game', 9.165),
#  ('general', 1.0),
#  ('goal', 1.0),
#  ('ground', 2.0),
#  ('hack', 1.0),
#  ('half', 2.0),
#  ('hearts', 1.0),
#  ('kick', 1.0),
#  ('kick', 2.0),
#  ('leather', 1.0),
#  ('package', 1.0),
#  ('pass', 1.0),
#  ('pass', 2.999),
#  ('passing', 2.0),
#  ('pigskin', 1.0),
#  ('projectile', 1.0),
#  ('quarter', 2.0),
#  ('rangers', 1.0),
#  ('return', 2.0),
#  ('roof', 1.0),
#  ('rough', 1.0),
#  ('round', 1.0),
#  ('rugby', 1.0),
#  ('rugby', 2.0),
#  ('run', 1.0),
#  ('running', 2.0),
#  ('rush', 1.0),
#  ('safety', 1.0),
#  ('snap', 1.0),
#  ('soccer_ball', 1.0),
#  ('solo', 1.0),
#  ('spike', 1.0),
#  ('sport', 8.0),
#  ('strip', 1.0),
#  ('sub', 1.0),
#  ('tackle', 1.0),
#  ('tackle', 2.0),
#  ('team', 1.0),
#  ('toss', 1.0),
#  ('united', 1.0),
#  ('wednesday', 1.0),
#  ('zone', 1.0)}

# %%
with open('../data/kb/conceptnet_base.pkl', 'wb') as f:
    pickle.dump(concept_dict, f)

# %%
with open('../data/kb/labels_base.pkl', 'wb') as f:
    pickle.dump(labels_set, f)

# %% [markdown]
# ### NRC

# %%
df = pd.read_csv("../data/kb/NRC-VAD-Lexicon.txt", sep='\t')

# %%
NRC_dict = {}
for i, row in df.iterrows():
    NRC_dict[row[0]] = tuple(row[1:])
    
with open('../data/kb/NRC_base.pkl', 'wb') as f:   
    pickle.dump(NRC_dict, f)

# %% [markdown]
# ### SenticNet

# %%
# everything in NRC, copy one from senticnet
# pleasentness attention sensitivity aptitude polarity

sn = SenticNet()

senticnet_dict = dict()
for key, value in sn.data.items():
    senticnet_dict[key] = (value[0], value[1], value[2], value[3], value[7])
    
with open('../data/kb/senticnet_base.pkl', 'wb') as f:   
    pickle.dump(senticnet_dict, f)

# %% [markdown]
# ### Test

# %%
with open('../data/kb/conceptnet_base.pkl', 'rb') as f:
    concepts = pickle.load(f)

with open('../data/kb/NRC_base.pkl', 'rb') as f:
    NRCs = pickle.load(f)
    
with open('../data/kb/labels_base.pkl', 'rb') as f:
    labels_test = pickle.load(f)
    
with open('../data/kb/senticnet_base.pkl', 'rb') as f:   
    senticnets = pickle.load(f)

# %%
concepts['birthday']
# Out:
# {('28th_february_1980', 1.0),
#  ('about', 0.145),
#  ('about_age', 0.145),
#  ('ad_günü', 1.0),
#  ('added', 0.129),
#  ('adlawng_natawhan', 1.0),
#  ('afmælisdagur', 1.0),
#  ('again', 0.223),
#  ('age', 0.102),
#  ('age', 4.073),
#  ('age', 8.203),
#  ('age_anniversary', 1.234),
#  ('age_celebration', 3.47),
#  ('age_commemoration', 0.189),
#  ('age_counter', 0.227),
#  ('age_counting', 0.239),
#  ('age_date', 0.609),
#  ('age_day', 0.713),
#  ('age_event', 0.381),
#  ('age_holiday', 0.476),
#  ('age_marker', 0.186),
#  ('age_party', 1.134),
#  ('age_progression', 0.194),
#  ('age_related', 0.641),
#  ('age_tracking', 0.193),
#  ('ageing', 0.422),
#  ('ageing_celebration', 0.278),
#  ('ages', 0.22),
#  ('aging', 1.811),
#  ('aging_celebration', 0.293),
#  ('ago', 0.134),
#  ('alive', 0.183),
#  ('aniversare', 1.0),
#  ('aniversari', 1.0),
#  ('aniversari', 2.0),
#  ('aniversario', 1.0),
#  ('aniversário', 2.0),
#  ('anivèsè', 1.0),
#  ('anniversaire', 1.0),
#  ('anniversari', 1.0),
#  ('anniversarie', 1.0),
#  ('anniversariu', 1.0),
#  ('anniversary', 0.217),
#  ('anniversary', 1.0),
#  ('anniversary', 2.0),
#  ('anniversary', 6.919),
#  ('anniversary_birth', 0.582),
#  ('anniversary_born', 0.378),
#  ('anniversary_day', 0.2),
#  ('annual', 7.953),
#  ('annual_age', 0.22),
#  ('annual_anniversary', 0.381),
#  ('annual_birth', 0.251),
#  ('annual_cake', 0.173),
#  ('annual_celebration', 4.29),
#  ('annual_date', 0.222),
#  ('annual_day', 0.821),
#  ('annual_event', 1.0),
#  ('annual_event', 2.866),
#  ('annual_holiday', 0.276),
#  ('annual_life', 0.144),
#  ('annual_occasion', 0.172),
#  ('annual_occurrence', 0.527),
#  ('annual_party', 2.147),
#  ('annually', 0.82),
#  ('annually_thing', 0.167),
#  ('another', 0.327),
#  ('another_year', 0.327),
#  ('asofānau', 1.0),
#  ('bake_cake', 2.0),
#  ('bake_cake', 3.464),
#  ('baking_cake', 2.0),
#  ('balloons', 1.321),
#  ('balloons_cake', 0.122),
#  ('balloons_presents', 0.186),
#  ('becoming', 0.293),
#  ('becoming_old', 0.293),
#  ('being', 1.723),
#  ('being_born', 1.723),
#  ('betde', 1.0),
#  ('birth', 0.159),
#  ('birth', 1.0),
#  ('birth', 5.888),
#  ('birth_anniversary', 2.437),
#  ('birth_celebrate', 0.373),
#  ('birth_celebration', 1.709),
#  ('birthdai', 0.25),
#  ('birthdate', 1.0),
#  ('birthday_boy', 1.0),
#  ('birthday_cake', 1.0),
#  ('birthday_card', 1.0),
#  ('birthday_effect', 1.0),
#  ('birthday_girl', 1.0),
#  ('birthday_party', 1.0),
#  ('birthday_present', 1.0),
#  ('birthdayed', 1.0),
#  ('birthdaying', 1.0),
#  ('birthdayish', 1.0),
#  ('birthdayless', 1.0),
#  ('birthdays', 1.0),
#  ('birtheday', 0.25),
#  ('blanks', 0.218),
#  ('blow', 0.143),
#  ('blow', 0.504),
#  ('blow_candles', 0.143),
#  ('blow_out_candles_when', 1.0),
#  ('bluegown', 1.0),
#  ('born', 0.631),
#  ('born', 8.641),
#  ('born_anniversary', 0.746),
#  ('born_celebrate', 0.136),
#  ('born_celebration', 0.556),
#  ('born_date', 2.434),
#  ('born_on', 0.68),
#  ('born_party', 0.156),
#  ('born_time', 0.247),
#  ('breithlá', 1.0),
#  ('bumps', 1.0),
#  ('bursdag', 1.0),
#  ('buy', 1.0),
#  ('buy_for_loved_one', 3.464),
#  ('buy_for_loved_one', 4.472),
#  ('buy_present_for_friend', 1.0),
#  ('buy_presents', 1.0),
#  ('buy_presents_for_others', 2.0),
#  ('buying_presents', 2.828),
#  ('buying_presents_for_others', 1.0),
#  ('cake', 2.0),
#  ('cake', 9.968),
#  ('cake', 15.236),
#  ('cake_anniversary', 0.103),
#  ('cake_balloons', 0.307),
#  ('cake_candle', 0.303),
#  ('cake_candles', 3.591),
#  ('cake_celebration', 0.61),
#  ('cake_day', 0.786),
#  ('cake_dessert', 0.176),
#  ('cake_eating', 0.148),
#  ('cake_event', 0.278),
#  ('cake_gifts', 0.128),
#  ('cake_holiday', 0.415),
#  ('cake_icing', 0.183),
#  ('cake_parties', 0.216),
#  ('cake_party', 1.019),
#  ('cake_presents', 1.435),
#  ('cake_reason', 0.173),
#  ('cake_surprise', 0.229),
#  ('cakes', 2.085),
#  ('cakes_candles', 0.643),
#  ('cakes_presents', 0.129),
#  ('cakes_ribbons', 0.174),
#  ('candle', 0.146),
#  ('candle', 1.049),
#  ('candle_cake', 0.646),
#  ('candle_cakes', 0.1),
#  ('candled', 0.611),
#  ('candled_cake', 0.611),
#  ('candles', 6.258),
#  ('candles_cake', 2.219),
#  ('candles_cakes', 0.102),
#  ('candles_gifts', 0.146),
#  ('candles_icing', 0.175),
#  ('candles_party', 0.183),
#  ('candles_presents', 0.14),
#  ('candles_wishes', 0.171),
#  ('card', 0.305),
#  ('card', 2.828),
#  ('card', 4.425),
#  ('card_cake', 0.137),
#  ('celebrate', 1.0),
#  ('celebrate', 2.697),
#  ('celebrate_age', 0.598),
#  ('celebrate_birth', 0.642),
#  ('celebrate_life', 0.177),
#  ('celebrate_yearly', 0.219),
#  ('celebrated', 0.805),
#  ('celebrated_annually', 0.158),
#  ('celebrated_yearly', 0.342),
#  ('celebrating', 1.0),
#  ('celebrating', 2.449),
#  ('celebrating_age', 0.96),
#  ('celebrating_birth', 0.449),
#  ('celebrating_born', 0.169),
#  ('celebrating_you', 0.18),
#  ('celebration', 1.0),
#  ('celebration', 11.686),
#  ('celebration_age', 0.309),
#  ('celebration_annual', 0.477),
#  ('celebration_birth', 0.473),
#  ('celebration_born', 0.154),
#  ('celebration_cake', 0.105),
#  ('celebration_date', 0.102),
#  ('celebration_day', 1.344),
#  ('celebration_individually', 0.158),
#  ('celebration_life', 0.104),
#  ('celebration_of', 0.179),
#  ('celebration_yearly', 0.223),
#  ('celebratory', 0.379),
#  ('celebratory_cake', 0.103),
#  ('celebratory_date', 0.276),
#  ('ceremony', 0.446),
#  ('childbirth', 0.23),
#  ('children', 0.424),
#  ('children_love', 0.151),
#  ('christmas', 0.176),
#  ('christmas', 2.937),
#  ('co_latha_breith', 1.0),
#  ('coming', 0.213),
#  ('coming_age', 0.213),
#  ('commemoration', 0.189),
#  ('compleani', 1.0),
#  ('compleann', 1.0),
#  ('compleanno', 2.0),
#  ('compleano', 1.0),
#  ('counter', 0.227),
#  ('counting', 0.355),
#  ('counting_age', 0.116),
#  ('cumpleaño', 1.0),
#  ('cumpleaños', 1.0),
#  ('cumpleaños', 2.0),
#  ('cyclic', 0.299),
#  ('cyclic_occurrence', 0.299),
#  ('date', 0.282),
#  ('date', 2.0),
#  ('date', 6.814),
#  ('date_birth', 1.213),
#  ('date_born', 1.556),
#  ('date_de_naissance', 1.0),
#  ('date_of_birth', 1.0),
#  ('day', 0.285),
#  ('day', 1.0),
#  ('day', 9.545),
#  ('day_born', 4.503),
#  ('day_of', 0.292),
#  ('day_one', 0.166),
#  ('dead', 0.148),
#  ('dead_day', 0.148),
#  ('death', 1.627),
#  ('death_anniversary', 0.217),
#  ('death_date', 0.282),
#  ('death_time', 0.143),
#  ('deathday', 0.25),
#  ('deathday', 1.0),
#  ('december', 0.124),
#  ('decorated', 0.141),
#  ('decorated_cake', 0.141),
#  ('deiz_ha_bloaz', 1.0),
#  ('delicious', 0.188),
#  ('delicious_cake', 0.188),
#  ('dessert', 0.176),
#  ('die', 0.106),
#  ('die_natal', 1.0),
#  ('dies_natalis', 2.0),
#  ('ditëlindje', 1.0),
#  ('dob', 0.284),
#  ('doglan_güni', 1.0),
#  ('doğum_günü', 1.0),
#  ('doğğan_künü', 1.0),
#  ('dzimšanas_diena', 1.0),
#  ('each', 0.535),
#  ('each_year', 0.535),
#  ('eat', 0.252),
#  ('eat_cake', 0.252),
#  ('eating', 0.148),
#  ('egg', 0.262),
#  ('egun', 1.0),
#  ('eighteenth', 1.0),
#  ('elder', 0.113),
#  ('enjoy_company_of_friends', 1.0),
#  ('event', 0.271),
#  ('event', 5.744),
#  ('every', 2.337),
#  ('every_person', 0.159),
#  ('every_year', 1.0),
#  ('every_year', 2.196),
#  ('everyone', 0.64),
#  ('everyone_has', 0.148),
#  ('far', 0.108),
#  ('fellow', 0.103),
#  ('first', 0.63),
#  ('first_day', 0.329),
#  ('first_life', 0.132),
#  ('for_age', 0.183),
#  ('for_aging', 0.168),
#  ('for_birth', 0.199),
#  ('for_everyone', 0.232),
#  ('for_you', 0.146),
#  ('forever', 0.1),
#  ('forever_sunset', 0.1),
#  ('form_of_celebration', 1.0),
#  ('fortieth', 0.143),
#  ('friends', 0.116),
#  ('friyaridei', 1.0),
#  ('fun', 1.329),
#  ('funeral', 0.465),
#  ('fæðingardagur', 1.0),
#  ('fête', 1.0),
#  ('födelsedag', 2.0),
#  ('fødselsdag', 1.0),
#  ('føðingardagur', 1.0),
#  ('geboortedag', 0.25),
#  ('geboortsdag', 1.0),
#  ('gebuertsdag', 1.0),
#  ('gebursdag', 1.0),
#  ('geburtstag', 0.25),
#  ('geburtstag', 1.0),
#  ('gebuursdai', 0.25),
#  ('gebuursdai', 1.0),
#  ('gebyrddæg', 0.25),
#  ('gebyrddæg', 1.0),
#  ('genethliac', 1.0),
#  ('get_old', 0.127),
#  ('getting', 1.094),
#  ('getting_old', 1.094),
#  ('gift', 0.102),
#  ('gift', 0.38),
#  ('gift', 1.0),
#  ('gifts', 1.339),
#  ('gimtadienis', 1.0),
#  ('give_gift', 1.0),
#  ('give_gift', 2.828),
#  ('giving', 0.164),
#  ('giving_birth', 0.164),
#  ('giving_gift', 2.0),
#  ('grow', 0.147),
#  ('grow_old', 0.147),
#  ('growing', 0.436),
#  ('growing_old', 0.149),
#  ('growing_up', 0.287),
#  ('guests', 0.141),
#  ('għeluq_snin', 1.0),
#  ('half', 0.159),
#  ('half_birth', 0.159),
#  ('half_birthday', 1.0),
#  ('happiest', 0.153),
#  ('happiest_day', 0.153),
#  ('happy', 0.132),
#  ('happy', 0.224),
#  ('happy', 4.162),
#  ('happy_birthday', 1.0),
#  ('happy_blanks', 0.218),
#  ('happy_celebration', 0.143),
#  ('happy_day', 1.361),
#  ('happy_occasion', 0.432),
#  ('happy_time', 0.294),
#  ('happy_time', 1.0),
#  ('happy_what', 0.156),
#  ('happy_you', 0.213),
#  ('hari_lahir', 1.0),
#  ('has', 1.377),
#  ('has_balloons', 0.137),
#  ('has_cake', 0.864),
#  ('has_song', 0.228),
#  ('have_good_one', 1.0),
#  ('have_party', 2.828),
#  ('hello', 0.103),
#  ('holiday', 5.764),
#  ('holiday_yearly', 0.204),
#  ('how', 0.566),
#  ('how_old', 0.566),
#  ('hoʼdizhchínę́ęjį́_anáyííłką́', 1.0),
#  ('human', 0.488),
#  ('human_anniversary', 0.311),
#  ('human_celebration', 0.177),
#  ('icing', 0.547),
#  ('icing_cake', 0.189),
#  ('importance', 0.137),
#  ('in_december', 0.124),
#  ('increasing', 0.15),
#  ('increasing_age', 0.15),
#  ('individual', 0.306),
#  ('individually', 0.158),
#  ('innìhta', 1.0),
#  ('ipenonasne_watane', 1.0),
#  ('is_born', 0.15),
#  ('isabukuru', 1.0),
#  ('jesus', 0.135),
#  ('jesus_holiday', 0.135),
#  ('jierdei', 1.0),
#  ('joined', 0.141),
#  ('joined_together', 0.141),
#  ('jour_de_naissance', 1.0),
#  ('jour_de_naissànse', 1.0),
#  ('joyous', 0.217),
#  ('joyous_date', 0.217),
#  ('kaarawan', 1.0),
#  ('kanreki', 1.0),
#  ('kids', 0.148),
#  ('kumpleanyos', 1.0),
#  ('la_hanau', 1.0),
#  ('laa_ruggyree', 1.0),
#  ('life', 0.861),
#  ('life_celebration', 0.408),
#  ('lifetable', 1.0),
#  ('like', 0.278),
#  ('like_anniversary', 0.102),
#  ('like_christmas', 0.176),
#  ('love', 0.151),
#  ('là_breith', 1.0),
#  ('lá_breithe', 1.0),
#  ('magician', 0.118),
#  ('mail_letter', 1.0),
#  ('marker', 0.186),
#  ('marking', 0.148),
#  ('marking_age', 0.148),
#  ('marks', 0.22),
#  ('marks_ages', 0.22),
#  ('mawlid', 1.0),
#  ('meaning', 0.329),
#  ('mine', 0.15),
#  ('mirth', 0.219),
#  ('month', 0.149),
#  ('motedadel', 1.0),
#  ('mothers', 0.415),
#  ('mothers_womb', 0.415),
#  ('naked', 0.132),
#  ('naked_suit', 0.132),
#  ('name_day', 1.0),
#  ('narodeniny', 1.0),
#  ('narodniny', 1.0),
#  ('narodny_źeń', 1.0),
#  ('narozeniny', 2.0),
#  ('naskiĝdatreveno', 1.0),
#  ('naskiĝotago', 1.0),
#  ('naskiĝtago', 1.0),
#  ('naskodio', 1.0),
#  ('naskotago', 1.0),
#  ('natal', 1.656),
#  ('natal_anniversary', 0.17),
#  ('natal_day', 0.952),
#  ('natal_day', 2.0),
#  ('natal_time', 0.173),
#  ('natalici', 1.0),
#  ('natalicio', 1.0),
#  ('natalis', 2.0),
#  ('natalitial', 1.0),
#  ('natalizi', 1.0),
#  ('nativity', 0.147),
#  ('new', 0.102),
#  ('new', 0.354),
#  ('new_age', 0.102),
#  ('new_age', 0.354),
#  ('newborn', 0.173),
#  ('night', 0.11),
#  ('ninny', 0.138),
#  ('numbers', 0.332),
#  ('occasion', 0.12),
#  ('occasion', 3.213),
#  ('occurrence', 0.995),
#  ('of_age', 0.153),
#  ('of_birth', 0.814),
#  ('of_you', 0.16),
#  ('old', 2.981),
#  ('once', 3.247),
#  ('once_year', 2.349),
#  ('once_yearly', 1.409),
#  ('one_day', 0.478),
#  ('one_person', 0.19),
#  ('one_year', 0.729),
#  ('opening_gift', 1.0),
#  ('origin', 0.363),
#  ('origin_day', 0.147),
#  ('origins', 0.17),
#  ('own', 0.184),
#  ('own_celebration', 0.184),
#  ('part', 0.173),
#  ('parties', 1.272),
#  ('party', 1.0),
#  ('party', 7.689),
#  ('party', 8.444),
#  ('party_bag', 1.0),
#  ('party_cake', 0.356),
#  ('party_celebration', 0.184),
#  ('party_day', 0.661),
#  ('party_event', 0.289),
#  ('party_friends', 0.116),
#  ('party_gifts', 0.127),
#  ('party_occasion', 0.174),
#  ('party_presents', 0.139),
#  ('party_reason', 0.167),
#  ('party_time', 0.32),
#  ('party_with', 0.164),
#  ('passing', 0.143),
#  ('pedn_bloodh', 1.0),
#  ('pen_blwydd', 1.0),
#  ('penblwydd', 1.0),
#  ('penn_bloodh', 1.0),
#  ('per', 0.208),
#  ('per_year', 0.208),
#  ('person', 0.865),
#  ('personal', 3.841),
#  ('personal_age', 0.146),
#  ('personal_anniversary', 0.206),
#  ('personal_celebration', 0.555),
#  ('personal_day', 0.269),
#  ('personal_holiday', 2.76),
#  ('personal_party', 0.162),
#  ('piligadma', 1.0),
#  ('pinata', 1.0),
#  ('present', 1.557),
#  ('presents', 3.831),
#  ('presents_cake', 0.405),
#  ('presents_party', 0.135),
#  ('progression', 0.194),
#  ('put', 0.232),
#  ('put_together', 0.232),
#  ('quinceañera', 1.0),
#  ('ramanavami', 1.0),
#  ('reason', 0.34),
#  ('rebirthday', 0.25),
#  ('related', 0.641),
#  ('remembering', 0.159),
#  ('remembering_birth', 0.159),
#  ('ribbons', 0.174),
#  ('riegádanbeaivi', 1.0),
#  ('roindupäivy', 1.0),
#  ('rojstni_dan', 1.0),
#  ('rođendan', 2.828),
#  ('rā_huritau', 1.0),
#  ('sanyɛlɛma', 1.0),
#  ('see_old_things', 1.0),
#  ('self', 0.198),
#  ('self_holiday', 0.198),
#  ('send', 0.168),
#  ('send_card', 0.168),
#  ('send_e_mail', 1.0),
#  ('sigaanisucu', 1.0),
#  ('siganisucu', 1.0),
#  ('siku_ya_kuzaliwa', 1.0),
#  ('siku_ya_uzalishi', 1.0),
#  ('singing', 0.18),
#  ('singing_happy', 0.18),
#  ('sinh_nhật', 1.0),
#  ('some_day', 0.189),
#  ('something', 0.143),
#  ('song', 0.228),
#  ('special', 4.97),
#  ('special_cake', 0.284),
#  ('special_date', 0.671),
#  ('special_day', 3.122),
#  ('special_event', 0.714),
#  ('special_holiday', 0.242),
#  ('special_meaning', 0.329),
#  ('special_moment', 1.0),
#  ('special_occasion', 1.035),
#  ('special_time', 0.269),
#  ('suit', 0.338),
#  ('sunday', 0.158),
#  ('sunset', 0.1),
#  ('surprise', 0.366),
#  ('surprise', 5.187),
#  ('surprising', 1.0),
#  ('sweet_seventeen', 1.0),
#  ('sweet_sixteen', 1.0),
#  ('synttärit', 1.0),
#  ('syntymäpäivä', 2.0),
#  ('születésnap', 2.0),
#  ('sünnipäev', 2.0),
#  ('thing', 0.169),
#  ('time', 0.143),
#  ('time', 1.303),
#  ('together', 0.373),
#  ('tracking', 0.193),
#  ('tradition', 0.6),
#  ('tugʻilan_kun', 1.0),
#  ('twenty', 0.169),
#  ('twenty_first', 0.169),
#  ('twenty_first', 1.0),
#  ('type', 0.165),
#  ('type_party', 0.165),
#  ('ulang_tahun', 1.0),
#  ('unbirthday', 1.0),
#  ('up', 0.287),
#  ('urodziny', 2.0),
#  ('urtebetetze', 1.0),
#  ('urtemuga', 1.0),
#  ('usuku_lokuzalwa', 1.0),
#  ('verjaardag', 2.0),
#  ('verjaarsdag', 1.0),
#  ('verjaordag', 1.0),
#  ('wata_junt_ay', 1.0),
#  ('what', 0.303),
#  ('what_you', 0.147),
#  ('when', 2.334),
#  ('when_birth', 0.189),
#  ('when_born', 2.027),
#  ('when_you', 0.146),
#  ('wiki', 0.25),
#  ('wish', 0.282),
#  ('wishes', 0.171),
#  ('with_cake', 0.508),
#  ('wn31', 1.0),
#  ('womb', 0.415),
#  ('x', 0.115),
#  ('x_party', 0.115),
#  ('year', 0.576),
#  ('year', 5.347),
#  ('year_ago', 0.134),
#  ('year_born', 0.139),
#  ('year_celebrate', 0.177),
#  ('year_celebration', 0.104),
#  ('year_elder', 0.113),
#  ('year_old', 0.361),
#  ('yearly', 7.001),
#  ('yearly_aging', 0.101),
#  ('yearly_anniversary', 0.975),
#  ('yearly_birth', 0.184),
#  ('yearly_celebrate', 0.26),
#  ('yearly_celebration', 3.35),
#  ('yearly_date', 0.252),
#  ('yearly_event', 1.578),
#  ('yearly_holiday', 0.629),
#  ('yearly_occasion', 0.17),
#  ('yearly_party', 0.81),
#  ('yearly_thing', 0.186),
#  ('years', 1.4),
#  ('years_added', 0.129),
#  ('years_alive', 0.183),
#  ('years_old', 0.485),
#  ('years_passing', 0.143),
#  ('you', 1.028),
#  ('you_born', 0.66),
#  ('you_were', 0.141),
#  ('zi_de_naștere', 1.0),
#  ('γενεθλια', 1.0),
#  ('день_народження', 1.0),
#  ('день_рождения', 1.0),
#  ('дзень_нараджэння', 1.0),
#  ('днюха', 1.0),
#  ('народенины', 1.0),
#  ('роденден', 1.0),
#  ('рожден_ден', 1.0),
#  ('рузи_таваллуд', 1.0),
#  ('таваллуд', 1.0),
#  ('туулган_күнү', 1.0),
#  ('туған_күн', 1.0),
#  ('тыуған_көн', 1.0),
#  ('төрсөн_өдөр', 1.0),
#  ('төрүттүнген_хүнү', 1.0),
#  ('ծննդյան_օր', 1.0),
#  ('ծնունդ', 1.0),
#  ('געבוירן_טאג', 1.0),
#  ('געבורטסטאג', 1.0),
#  ('יום_הולדת', 1.0),
#  ('تولد', 1.0),
#  ('سالگرہ', 1.0),
#  ('عيد_ميلاد', 1.0),
#  ('जन्मदिन', 1.0),
#  ('वाट_दिवस', 1.0),
#  ('জন্মদিন', 1.0),
#  ('ਜਨਮ_ਦਿਨ', 1.0),
#  ('વરસ_ગાનત', 1.0),
#  ('ଜନ୍ମଦିନ', 1.0),
#  ('பிறந்தநாள்', 1.0),
#  ('జన్మదినము', 1.0),
#  ('ಜನ್ಮದಿನ', 1.0),
#  ('උපන්_දිනය', 1.0),
#  ('วันเกิด', 1.0),
#  ('ຊົນມະທິ', 1.0),
#  ('ມື້ເກີດ', 1.0),
#  ('ວັນຄ້າຍວັນເກີດ', 1.0),
#  ('ວັນເກີດ', 1.0),
#  ('မွေးနေ့', 1.0),
#  ('დაბადების_დღე', 1.0),
#  ('ልደታ', 1.0),
#  ('ልደት', 1.0),
#  ('ថ្ងៃខួប', 1.0),
#  ('ᦞᧃᦵᦂᦲᧆᧉ', 1.0),
#  ('バースデー', 1.0),
#  ('牛一', 1.0),
#  ('生日', 1.0),
#  ('生日', 2.0),
#  ('生辰', 1.0),
#  ('誕生日', 1.0),
#  ('생신', 1.0),
#  ('생일', 1.0)}

# %%
NRCs['picture']
# Out:
# (0.7140000000000001, 0.308, 0.462)

# %%
senticnets['picture']
# Out:
# ('0.034', '0.075', '0', '0.143', '0.084')
